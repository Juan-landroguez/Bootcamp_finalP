# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #This file will complement the all_movies_cleanned, therefore I'll do some adjustments to avoid issues when I'll merge them.

# %%
a_oscars = pd.read_csv('the_oscar_award.csv')
display(a_oscars.head(60), a_oscars.shape)
# Out:
#     year_film  year_ceremony  ceremony                      category  \
# 0        1927           1928         1                         ACTOR
# 1        1927           1928         1                         ACTOR
# 2        1927           1928         1                       ACTRESS
# 3        1927           1928         1                       ACTRESS
# 4        1927           1928         1                       ACTRESS
# 5        1927           1928         1                 ART DIRECTION
# 6        1927           1928         1                 ART DIRECTION
# 7        1927           1928         1                 ART DIRECTION
# 8        1927           1928         1                CINEMATOGRAPHY
# 9        1927           1928         1                CINEMATOGRAPHY
# 10       1927           1928         1                CINEMATOGRAPHY
# 11       1927           1928         1    DIRECTING (Comedy Picture)
# 12       1927           1928         1    DIRECTING (Comedy Picture)
# 13       1927           1928         1  DIRECTING (Dramatic Picture)
# 14       1927           1928         1  DIRECTING (Dramatic Picture)
# 15       1927           1928         1  DIRECTING (Dramatic Picture)
# 16       1927           1928         1           ENGINEERING EFFECTS
# 17       1927           1928         1           ENGINEERING EFFECTS
# 18       1927           1928         1           ENGINEERING EFFECTS
# 19       1927           1928         1           OUTSTANDING PICTURE
# 20       1927           1928         1           OUTSTANDING PICTURE
# 21       1927           1928         1           OUTSTANDING PICTURE
# 22       1927           1928         1   UNIQUE AND ARTISTIC PICTURE
# 23       1927           1928         1   UNIQUE AND ARTISTIC PICTURE
# 24       1927           1928         1   UNIQUE AND ARTISTIC PICTURE
# 25       1927           1928         1          WRITING (Adaptation)
# 26       1927           1928         1          WRITING (Adaptation)
# 27       1927           1928         1          WRITING (Adaptation)
# 28       1927           1928         1      WRITING (Original Story)
# 29       1927           1928         1      WRITING (Original Story)
# 30       1927           1928         1       WRITING (Title Writing)
# 31       1927           1928         1       WRITING (Title Writing)
# 32       1927           1928         1       WRITING (Title Writing)
# 33       1927           1928         1                 SPECIAL AWARD
# 34       1927           1928         1                 SPECIAL AWARD
# 35       1928           1929         2                         ACTOR
# 36       1928           1929         2                         ACTOR
# 37       1928           1929         2                         ACTOR
# 38       1928           1929         2                         ACTOR
# 39       1928           1929         2                         ACTOR
# 40       1928           1929         2                       ACTRESS
# 41       1928           1929         2                       ACTRESS
# 42       1928           1929         2                       ACTRESS
# 43       1928           1929         2                       ACTRESS
# 44       1928           1929         2                       ACTRESS
# 45       1928           1929         2                       ACTRESS
# 46       1928           1929         2                 ART DIRECTION
# 47       1928           1929         2                 ART DIRECTION
# 48       1928           1929         2                 ART DIRECTION
# 49       1928           1929         2                 ART DIRECTION
# 50       1928           1929         2                 ART DIRECTION
# 51       1928           1929         2                CINEMATOGRAPHY
# 52       1928           1929         2                CINEMATOGRAPHY
# 53       1928           1929         2                CINEMATOGRAPHY
# 54       1928           1929         2                CINEMATOGRAPHY
# 55       1928           1929         2                CINEMATOGRAPHY
# 56       1928           1929         2                     DIRECTING
# 57       1928           1929         2                     DIRECTING
# 58       1928           1929         2                     DIRECTING
# 59       1928           1929         2                     DIRECTING
#
#                        name                               film  winner
# 0       Richard Barthelmess                          The Noose   False
# 1             Emil Jannings                   The Last Command    True
# 2            Louise Dresser                    A Ship Comes In   False
# 3              Janet Gaynor                         7th Heaven    True
# 4            Gloria Swanson                     Sadie Thompson   False
# 5             Rochus Gliese                            Sunrise   False
# 6   William Cameron Menzies                          The Dove;    True
# 7              Harry Oliver                         7th Heaven   False
# 8             George Barnes                  The Devil Dancer;   False
# 9            Charles Rosher                            Sunrise    True
# 10              Karl Struss                            Sunrise    True
# 11          Lewis Milestone                Two Arabian Knights    True
# 12                Ted Wilde                             Speedy   False
# 13            Frank Borzage                         7th Heaven    True
# 14           Herbert Brenon                    Sorrell and Son   False
# 15               King Vidor                          The Crowd   False
# 16           Ralph Hammeras                                NaN   False
# 17              Roy Pomeroy                              Wings    True
# 18         Nugent Slaughter                                NaN   False
# 19        The Caddo Company                         The Racket   False
# 20                      Fox                         7th Heaven   False
# 21   Paramount Famous Lasky                              Wings    True
# 22                      Fox                            Sunrise    True
# 23      Metro-Goldwyn-Mayer                          The Crowd   False
# 24   Paramount Famous Lasky                              Chang   False
# 25              Alfred Cohn                    The Jazz Singer   False
# 26         Anthony Coldeway                     Glorious Betsy   False
# 27          Benjamin Glazer                         7th Heaven    True
# 28               Lajos Biro                   The Last Command   False
# 29                Ben Hecht                         Underworld    True
# 30             Gerald Duffy  The Private Life of Helen of Troy   False
# 31           Joseph Farnham                                NaN    True
# 32       George Marion, Jr.                                NaN   False
# 33             Warner Bros.                                NaN    True
# 34          Charles Chaplin                                NaN    True
# 35          George Bancroft                        Thunderbolt   False
# 36            Warner Baxter                     In Old Arizona    True
# 37           Chester Morris                              Alibi   False
# 38                Paul Muni                        The Valiant   False
# 39              Lewis Stone                        The Patriot   False
# 40          Ruth Chatterton                           Madame X   False
# 41            Betty Compson                         The Barker   False
# 42            Jeanne Eagels                         The Letter   False
# 43         Corinne Griffith                    The Divine Lady   False
# 44              Bessie Love                The Broadway Melody   False
# 45            Mary Pickford                           Coquette    True
# 46              Hans Dreier                        The Patriot   False
# 47           Cedric Gibbons         The Bridge of San Luis Rey    True
# 48          Mitchell Leisen                           Dynamite   False
# 49  William Cameron Menzies                             Alibi;   False
# 50             Harry Oliver                       Street Angel   False
# 51            George Barnes              Our Dancing Daughters   False
# 52           Clyde De Vinna    White Shadows in the South Seas    True
# 53            Arthur Edeson                     In Old Arizona   False
# 54            Ernest Palmer                       Four Devils;   False
# 55               John Seitz                    The Divine Lady   False
# 56         Lionel Barrymore                           Madame X   False
# 57           Harry Beaumont                The Broadway Melody   False
# 58          Irving Cummings                     In Old Arizona   False
# 59              Frank Lloyd                    The Divine Lady    True
# (10765, 7)

# %% [markdown]
# # Initial data exploration:

# %%
# Check the first few rows of the dataset
a_oscars.head()
# Out:
#    year_film  year_ceremony  ceremony category                 name  \
# 0       1927           1928         1    ACTOR  Richard Barthelmess
# 1       1927           1928         1    ACTOR        Emil Jannings
# 2       1927           1928         1  ACTRESS       Louise Dresser
# 3       1927           1928         1  ACTRESS         Janet Gaynor
# 4       1927           1928         1  ACTRESS       Gloria Swanson
#
#                film  winner
# 0         The Noose   False
# 1  The Last Command    True
# 2   A Ship Comes In   False
# 3        7th Heaven    True
# 4    Sadie Thompson   False

# %%
# Check the number of rows and columns
a_oscars.shape
# Out:
# (10765, 7)

# %%
# Check the data types of each column
a_oscars.dtypes
# Out:
# year_film         int64
# year_ceremony     int64
# ceremony          int64
# category         object
# name             object
# film             object
# winner             bool
# dtype: object

# %%
# Check for missing values in each column
a_oscars.isnull().sum()
# Out:
# year_film          0
# year_ceremony      0
# ceremony           0
# category           0
# name               4
# film             315
# winner             0
# dtype: int64

# %%
# Check the number of unique values in each column
a_oscars.nunique()
# Out:
# year_film          95
# year_ceremony      95
# ceremony           95
# category          115
# name             6952
# film             4991
# winner              2
# dtype: int64

# %%
# Check for duplicates in each column
for col in a_oscars.columns:
    print(f"{col}: {a_oscars.duplicated(col).sum()}")
# Out:
# year_film: 10670
# year_ceremony: 10670
# ceremony: 10670
# category: 10650
# name: 3812
# film: 5773
# winner: 10763

# %% [markdown]
# # After the first exploration I'm going to start cleanning

# %%
a_oscars.columns
# Out:
# Index(['year_film', 'year_ceremony', 'ceremony', 'category', 'name', 'film',
#        'winner'],
#       dtype='object')

# %%
# Use the rename method to change the column name to be the same of the all_films dataframe
a_oscars.rename(columns={'film': 'movie_name'}, inplace=True)

# %%
#In order to improve the dataset I'll use for the proect, I'm going to clean and append all awards categories together, dividing in nominate and won.
#Also it's important to eliminate duplicate movies

# Fill missing values in 'category' column with an empty string
a_oscars['category'].fillna('', inplace=True)

# Group by 'movie_name' and aggregate the 'category' values for rows with 'winner' as False, and concatenate them
# with comma separator to create 'osc_nominated_awards'
a_oscars['osc_nominated_awards'] = a_oscars[a_oscars['winner'] == False].groupby('movie_name')['category'].apply(', '.join)

# Convert 'osc_nominated_awards' values to strings
a_oscars['osc_nominated_awards'] = a_oscars['osc_nominated_awards'].astype(str)

# Group by 'movie_name' and aggregate the 'category' values for rows with 'winner' as True, and concatenate them
looser = a_oscars[a_oscars['winner'] == False].groupby('movie_name')['category'].apply(lambda x: ', '.join(x)).reset_index()

# Merge the winners dataframe with the original dataframe
a_oscars = pd.merge(a_oscars, looser, on='movie_name', how='left')

# Rename the concatenated category column
a_oscars.rename(columns={'category_x': 'category', 'category_y': 'osc_nominated_categories'}, inplace=True)

# Group by 'movie_name' and aggregate the 'category' values for rows with 'winner' as True, and concatenate them
# with comma separator to create 'osc_won_awards'
a_oscars['osc_won_awards'] = a_oscars[a_oscars['winner'] == True].groupby('movie_name')['category'].apply(', '.join)

# Convert 'osc_won_awards' values to strings
a_oscars['osc_won_awards'] = a_oscars['osc_won_awards'].astype(str)


# Group by 'movie_name' and aggregate the 'category' values for rows with 'winner' as True, and concatenate them
winner = a_oscars[a_oscars['winner'] == True].groupby('movie_name')['category'].apply(lambda x: ', '.join(x)).reset_index()

# Merge the winners dataframe with the original dataframe
a_oscars = pd.merge(a_oscars, winner, on='movie_name', how='left')

# Rename the concatenated category column
a_oscars.rename(columns={'category_x': 'category', 'category_y': 'osc_won_categories'}, inplace=True)

# Drop unnecessary columns
a_oscars.drop(['osc_won_awards','osc_nominated_awards','category','winner' ], axis=1, inplace=True)

# Drop the duplicate rows based on 'movie_name' and keep the last occurrence (which has 'winner' as True)
a_oscars = a_oscars.drop_duplicates(subset='movie_name', keep='last')

# %%
#verifiying new shape
a_oscars.shape
# Out:
# (4992, 7)

# %%
# I want to add the number of nominations or awards

# define a function to count number of categories through commas
def count_commas(s):
    if pd.notna(s):
        return len(s.split(','))
    else:
        return 0

# Apply the function to the columns 'osc_nominated_categories' and 'osc_won_categories'
a_oscars['osc_nominated_num'] = a_oscars['osc_nominated_categories'].apply(count_commas)
a_oscars['osc_won_num'] = a_oscars['osc_won_categories'].apply(count_commas)

# %%
#As there aren't adding valuable information I'll drop few columns
a_oscars.drop(['year_ceremony','ceremony','year_film' ], axis=1, inplace=True)

# %%
#In order to be self explainatory I rename name

a_oscars.rename(columns={'name': 'person_awarded'}, inplace=True)

# %%
a_oscars
# Out:
#                                           person_awarded           movie_name  \
# 0                                    Richard Barthelmess            The Noose
# 2                                         Louise Dresser      A Ship Comes In
# 4                                         Gloria Swanson       Sadie Thompson
# 6                                William Cameron Menzies            The Dove;
# 8                                          George Barnes    The Devil Dancer;
# ...                                                  ...                  ...
# 10756         Written by Steven Spielberg & Tony Kushner        The Fabelmans
# 10757                              Written by Todd Field                  Tár
# 10758                           Written by Ruben Östlund  Triangle of Sadness
# 10763                                          Iain Neil                  NaN
# 10764  To Ryan Laney for his innovative adaptation an...  Welcome to Chechnya
#
#                                 osc_nominated_categories  \
# 0                                                  ACTOR
# 2                                                ACTRESS
# 4                                                ACTRESS
# 6                                                    NaN
# 8                                         CINEMATOGRAPHY
# ...                                                  ...
# 10756  ACTOR IN A SUPPORTING ROLE, ACTRESS IN A LEADI...
# 10757  ACTRESS IN A LEADING ROLE, CINEMATOGRAPHY, DIR...
# 10758  DIRECTING, BEST PICTURE, WRITING (Original Scr...
# 10763                                                NaN
# 10764                                                NaN
#
#           osc_won_categories  osc_nominated_num  osc_won_num
# 0                        NaN                  1            0
# 2                        NaN                  1            0
# 4                        NaN                  1            0
# 6              ART DIRECTION                  0            1
# 8                        NaN                  1            0
# ...                      ...                ...          ...
# 10756                    NaN                  7            0
# 10757                    NaN                  6            0
# 10758                    NaN                  3            0
# 10763                    NaN                  0            0
# 10764  AWARD OF COMMENDATION                  0            1
#
# [4992 rows x 6 columns]

# %%
# Remove the 'person_awarded' column
a_oscars = a_oscars.drop('person_awarded', axis=1)

# Split text in 'osc_nominated_categories' by ',' and create new columns for each category
osc_nominated_categories = a_oscars['osc_nominated_categories'].str.split(',', expand=True)
osc_nominated_categories.columns = [f'osc_nominated_category{i+1}' for i in range(osc_nominated_categories.shape[1])]
a_oscars = pd.concat([a_oscars, osc_nominated_categories], axis=1)
a_oscars = a_oscars.drop('osc_nominated_categories', axis=1)

# Split text in 'osc_won_categories' by ',' and create new columns for each category
osc_won_categories = a_oscars['osc_won_categories'].str.split(',', expand=True)
osc_won_categories.columns = [f'osc_won_category{i+1}' for i in range(osc_won_categories.shape[1])]
a_oscars = pd.concat([a_oscars, osc_won_categories], axis=1)
a_oscars = a_oscars.drop('osc_won_categories', axis=1)

# Show the resulting DataFrame
a_oscars
# Out:
#                 movie_name  osc_nominated_num  osc_won_num  \
# 0                The Noose                  1            0
# 2          A Ship Comes In                  1            0
# 4           Sadie Thompson                  1            0
# 6                The Dove;                  0            1
# 8        The Devil Dancer;                  1            0
# ...                    ...                ...          ...
# 10756        The Fabelmans                  7            0
# 10757                  Tár                  6            0
# 10758  Triangle of Sadness                  3            0
# 10763                  NaN                  0            0
# 10764  Welcome to Chechnya                  0            1
#
#           osc_nominated_category1     osc_nominated_category2  \
# 0                           ACTOR                        None
# 2                         ACTRESS                        None
# 4                         ACTRESS                        None
# 6                             NaN                         NaN
# 8                  CINEMATOGRAPHY                        None
# ...                           ...                         ...
# 10756  ACTOR IN A SUPPORTING ROLE   ACTRESS IN A LEADING ROLE
# 10757   ACTRESS IN A LEADING ROLE              CINEMATOGRAPHY
# 10758                   DIRECTING                BEST PICTURE
# 10763                         NaN                         NaN
# 10764                         NaN                         NaN
#
#               osc_nominated_category3  osc_nominated_category4  \
# 0                                None                     None
# 2                                None                     None
# 4                                None                     None
# 6                                 NaN                      NaN
# 8                                None                     None
# ...                               ...                      ...
# 10756                       DIRECTING   MUSIC (Original Score)
# 10757                       DIRECTING             FILM EDITING
# 10758   WRITING (Original Screenplay)                     None
# 10763                             NaN                      NaN
# 10764                             NaN                      NaN
#
#       osc_nominated_category5         osc_nominated_category6  \
# 0                        None                            None
# 2                        None                            None
# 4                        None                            None
# 6                         NaN                             NaN
# 8                        None                            None
# ...                       ...                             ...
# 10756            BEST PICTURE               PRODUCTION DESIGN
# 10757            BEST PICTURE   WRITING (Original Screenplay)
# 10758                    None                            None
# 10763                     NaN                             NaN
# 10764                     NaN                             NaN
#
#               osc_nominated_category7  ... osc_won_category3  \
# 0                                None  ...               NaN
# 2                                None  ...               NaN
# 4                                None  ...               NaN
# 6                                 NaN  ...               NaN
# 8                                None  ...               NaN
# ...                               ...  ...               ...
# 10756   WRITING (Original Screenplay)  ...               NaN
# 10757                            None  ...               NaN
# 10758                            None  ...               NaN
# 10763                             NaN  ...               NaN
# 10764                             NaN  ...               NaN
#
#       osc_won_category4 osc_won_category5 osc_won_category6 osc_won_category7  \
# 0                   NaN               NaN               NaN               NaN
# 2                   NaN               NaN               NaN               NaN
# 4                   NaN               NaN               NaN               NaN
# 6                   NaN               NaN               NaN               NaN
# 8                   NaN               NaN               NaN               NaN
# ...                 ...               ...               ...               ...
# 10756               NaN               NaN               NaN               NaN
# 10757               NaN               NaN               NaN               NaN
# 10758               NaN               NaN               NaN               NaN
# 10763               NaN               NaN               NaN               NaN
# 10764               NaN               NaN               NaN               NaN
#
#       osc_won_category8 osc_won_category9 osc_won_category10  \
# 0                   NaN               NaN                NaN
# 2                   NaN               NaN                NaN
# 4                   NaN               NaN                NaN
# 6                   NaN               NaN                NaN
# 8                   NaN               NaN                NaN
# ...                 ...               ...                ...
# 10756               NaN               NaN                NaN
# 10757               NaN               NaN                NaN
# 10758               NaN               NaN                NaN
# 10763               NaN               NaN                NaN
# 10764               NaN               NaN                NaN
#
#       osc_won_category11 osc_won_category12
# 0                    NaN                NaN
# 2                    NaN                NaN
# 4                    NaN                NaN
# 6                    NaN                NaN
# 8                    NaN                NaN
# ...                  ...                ...
# 10756                NaN                NaN
# 10757                NaN                NaN
# 10758                NaN                NaN
# 10763                NaN                NaN
# 10764                NaN                NaN
#
# [4992 rows x 37 columns]

# %%
a_oscars.to_csv('a_oscars_cleaned.csv', index=False)
